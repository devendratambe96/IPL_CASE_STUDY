# %%
#importing all required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#uploading the csv file
df=pd.read_csv('Match.csv')

# %%
#first five records of the dataset
df.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  bye_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...         0
# 1     2  DA Warner    S Dhawan  TS Mills              0  ...         0
# 2     3  DA Warner    S Dhawan  TS Mills              0  ...         0
# 3     4  DA Warner    S Dhawan  TS Mills              0  ...         0
# 4     5  DA Warner    S Dhawan  TS Mills              0  ...         0
#
#    legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# ...

# %%
#displaying the columns in the dataset
df.columns
# Out:
# Index(['match_id', 'inning', 'batting_team', 'bowling_team', 'over', 'ball',
#        'batsman', 'non_striker', 'bowler', 'is_super_over', 'wide_runs',
#        'bye_runs', 'legbye_runs', 'noball_runs', 'penalty_runs',
#        'batsman_runs', 'extra_runs', 'total_runs', 'player_dismissed',
#        'dismissal_kind', 'fielder'],
#       dtype='object')

# %%
#look for different dismisasl kind
df['dismissal_kind'].value_counts()
# Out:
# caught               2029
# bowled                650
# run out               379
# lbw                   223
# stumped               121
# caught and bowled     106
# retired hurt            4
# hit wicket              4
# Name: dismissal_kind, dtype: int64

# %%
#find total runs scored by da warner
df['batsman_runs'].loc[df['batsman']=='DA Warner'].sum()
# Out:
# 1391

# %%
#Total runs scored by S Dhawan
df['batsman_runs'].loc[df['batsman']=='S Dhawan'].sum()
# Out:
# 1355

# %%
#Total runs score by V Kolhi

# %%
#extra runs given by ts mills
df['extra_runs'].loc[df['bowler']=='TS Mills'].sum()
# Out:
# 13

# %%
#find out how namy times da warner got out by lbw
len([(df['batsman']=='DA Warner') & (df['dismissal_kind']=='lbw')])
# Out:
# 1

# %%
#find how many times v kohli got cathch out
len(df[(df['batsman']=='V Kohli')&(df['dismissal_kind']=='caught')])
# Out:
# 36

# %%
#how many times ys chahal took wicket of da warner
df[(df['bowler']=='YS Chahal') & (df['player_dismissed']=='DA Warner')]
# Out:
# Empty DataFrame
# Columns: [match_id, inning, batting_team, bowling_team, over, ball, batsman, non_striker, bowler, is_super_over, wide_runs, bye_runs, legbye_runs, noball_runs, penalty_runs, batsman_runs, extra_runs, total_runs, player_dismissed, dismissal_kind, fielder]
# Index: []
#
# [0 rows x 21 columns]

# %%
# ya choudhari warner wicket
df[(df['bowler']=='A Choudhary') & (df['player_dismissed']=='DA Warner')]
# Out:
#     match_id  inning         batting_team                 bowling_team  over  \
# 11         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     2
#
#     ball    batsman non_striker       bowler  is_super_over  ...  bye_runs  \
# 11     5  DA Warner    S Dhawan  A Choudhary              0  ...         0
#
#     legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# 11            0            0             0             0           0
#
#     total_runs  player_dismissed dismissal_kind        fielder
# 11           0         DA Warner         caught  Mandeep Singh
#
# [1 rows x 21 columns]

# %%
#find numbers of stump out by ms dhoni
len(df[(df['fielder']=='MS Dhoni') & (df['dismissal_kind']=='stumped')])
# Out:
# 17

# %%
#find how many catches tsken bby  mandeep singh
len(df[(df['dismissal_kind']=='caught') & (df['fielder']=='Mandeep Singh')])
# Out:
# 7

# %%
#total rins scored by dhoni in 1 
df[(df['batsman']=='MS Dhoni') & (df['batsman_runs']==1)].sum()
# Out:
# C:\Users\devendra tambe\AppData\Local\Temp\ipykernel_100996\148299966.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df[(df['batsman']=='MS Dhoni') & (df['batsman_runs']==1)].sum()
# match_id                                                     72539
# inning                                                         688
# batting_team     Rising Pune SupergiantRising Pune SupergiantRi...
# bowling_team     Mumbai IndiansMumbai IndiansMumbai IndiansMumb...
# over                                                          7239
# ball                                                          1879
# batsman          MS DhoniMS DhoniMS DhoniMS DhoniMS DhoniMS Dho...
# non_striker      SPD SmithSPD SmithSPD SmithSPD SmithSPD SmithS...
# bowler           HH PandyaJJ BumrahMJ McClenaghanMJ McClenaghan...
# ...

# %%
df['batsman_runs'].loc[(df['batsman']=='MS Dhoni') & (df['batsman_runs']==1)].sum()
# Out:
# 517

# %%
#wkrts taken by chahal
len(df[(df['bowler']=='YS Chahal') & (df['player_dismissed'].notnull())])
# Out:
# 14

# %%
df.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  bye_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...         0
# 1     2  DA Warner    S Dhawan  TS Mills              0  ...         0
# 2     3  DA Warner    S Dhawan  TS Mills              0  ...         0
# 3     4  DA Warner    S Dhawan  TS Mills              0  ...         0
# 4     5  DA Warner    S Dhawan  TS Mills              0  ...         0
#
#    legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# ...

# %%
#Dismissials kind
df['dismissal_kind'].value_counts().plot(kind='bar')
plt.show()

# %%
#Catches Taken by RA Jadeja
df[(df['dismissal_kind']=='caught') & (df['fielder']=='RA Jadeja')]
# Out:
#        match_id  inning                 batting_team          bowling_team  \
# 3807         16       2               Mumbai Indians         Gujarat Lions
# 7018         30       1  Royal Challengers Bangalore         Gujarat Lions
# 15758        68       1              Deccan Chargers      Rajasthan Royals
# 16240        70       1  Royal Challengers Bangalore      Rajasthan Royals
# 16253        70       1  Royal Challengers Bangalore      Rajasthan Royals
# 23508       101       2  Royal Challengers Bangalore      Rajasthan Royals
# 26820       115       2             Delhi Daredevils      Rajasthan Royals
# 27133       117       1          Chennai Super Kings      Rajasthan Royals
# 27200       117       1          Chennai Super Kings      Rajasthan Royals
# 29203       126       2        Kolkata Knight Riders      Rajasthan Royals
# 33895       145       2              Kings XI Punjab      Rajasthan Royals
# ...

# %%
#total catches taken by RA Jadeja
len(df[(df['dismissal_kind']=='caught') & (df['fielder']=='RA Jadeja')])
# Out:
# 14

# %%
#total run out by RA Jadeja
len(df[(df['dismissal_kind']=='run out') & (df['fielder']=='RA Jadeja')])
# Out:
# 13

# %%
#total runs by V Kohli
df['batsman_runs'][df['batsman']=='V Kohli'].sum()
# Out:
# 1428
